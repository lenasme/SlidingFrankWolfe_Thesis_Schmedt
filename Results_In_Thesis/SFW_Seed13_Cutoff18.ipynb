# %%
import sys
sys.path.append('C:/Users/lenas/SFW_StepConstFunc')

# %%
import time
import importlib


import matplotlib as mpl
import matplotlib.cm as cm
import numpy as np
from math import sqrt, log
import matplotlib.pyplot as plt

# %%
from Setup.ground_truth import GroundTruth
from Setup.target_function import calculate_target_function
from Optimization_Functionals.rectangular_set import RectangularSet, construct_rectangular_set_from01
from Optimization_Utils.fine_optimization import run_fine_optimization
from Optimization.sliding_optimization import optimization_with_sliding

# %%
grid_size=100
deltas= [0.08-0.005, 0.09+0.005]
max_jumps=3
cut_off = 18
grid_size_coarse = 40
variance= 0.01
reg_param = 1/0.028 * np.sqrt(variance)
seed = 13

# %%
truncated_operator_applied_on_ground_truth, ground_truth, target_function_f = calculate_target_function(grid_size, deltas, max_jumps, cut_off, variance, seed, plot = True)

# %%
optimization_with_sliding(ground_truth, target_function_f, grid_size, grid_size_coarse, cut_off, reg_param, seed)
# Out:
# Optimal Rectangle initialized by outer boundary vertices of Primal-Dual result:
# 0 sets with weight < 0.015 deleted.
# Result before sliding step:
# 0 sets with weight < 0.015 deleted.
# Result after sliding step:
# 0 sets with weight < 0.015 deleted.
# Optimal Rectangle initialized by outer boundary vertices of Primal-Dual result:
# 0 sets with weight < 0.015 deleted.
# Result before sliding step:
# 0 sets with weight < 0.015 deleted.
# Result after sliding step:
# 0 sets with weight < 0.015 deleted.
# Optimal Rectangle initialized by outer boundary vertices of Primal-Dual result:
# 0 sets with weight < 0.015 deleted.
# Result before sliding step:
# 0 sets with weight < 0.015 deleted.
# Result after sliding step:
# 0 sets with weight < 0.015 deleted.
# Optimal Rectangle initialized by outer boundary vertices of Primal-Dual result:
# 0 sets with weight < 0.015 deleted.
# Result before sliding step:
# 0 sets with weight < 0.015 deleted.
# Result after sliding step:
# ...
